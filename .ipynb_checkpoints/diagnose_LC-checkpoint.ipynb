# %%
from diagnostics import *
# %matplotlib inline

# %%
# get data
planet, iteration = 8, 12
self = loadpickle('Results/TOIsensitivity27vettv3_mult2_planet%.5d_iteration%.3d/Sensitivity_class'%(planet,iteration))

# %%
#
plot_raw_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.541
# Ms       = 0.675
# Rs       = 0.625
# Teff     = 3996
# sig_phot = 384.9 ppm
#
# 2 injected planets:
# P  [days] = 0.827, 1.588
# rp        = 0.65, 2.11
# rp/Rs     = 0.00959, 0.03089
# (rp/Rs)^2 = 91.909683, 954.184159 ppm
# detected  = 0, 0
#
# 0 false positives:
# P [days] =

# %%
#
plot_corrected_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.541
# Ms       = 0.675
# Rs       = 0.625
# Teff     = 3996
# sig_phot = 384.9 ppm
#
# 2 injected planets:
# P  [days] = 0.827, 1.588
# rp        = 0.65, 2.11
# rp/Rs     = 0.00959, 0.03089
# (rp/Rs)^2 = 91.909683, 954.184159 ppm
# detected  = 0, 0
#
# 0 false positives:
# P [days] =

# %%
#
plot_transit_search(self, log=0)
# Out:
# Stellar parameters:
# Tmag     = 10.541
# Ms       = 0.675
# Rs       = 0.625
# Teff     = 3996
# sig_phot = 384.9 ppm
#
# 2 injected planets:
# P  [days] = 0.827, 1.588
# rp        = 0.65, 2.11
# rp/Rs     = 0.00959, 0.03089
# (rp/Rs)^2 = 91.909683, 954.184159 ppm
# detected  = 0, 0
#
# 0 false positives:
# P [days] =

# %%
#
check_confirm_transits(self, 2, 1.35, .5)
# Out:
# Confirming proposed transits...
# 0.0
# 0.2
# 0.4
# 0.6
# 0.8
# (array([[1.58765240e+00, 1.62417593e+03, 9.54673911e-04, 3.77752868e-02],
#         [2.54038930e+00, 1.62575101e+03, 1.48627986e-04, 5.92049661e-02],
#         [7.31737823e+00, 1.63052922e+03, 3.92571619e-04, 5.31095518e-02],
#         [1.52479650e+01, 1.63846562e+03, 1.21733811e-03, 6.44984275e-02],
#         [1.68338557e+01, 1.64005048e+03, 9.76615965e-04, 5.01118295e-02]]),
#  array([[1.58765247e+00, 1.62417593e+03, 9.54194729e-04, 3.78285119e-02]]),
#  array([143819.78769562]),
#  array([ True, False, False, False, False]),
#  array([ True, False, False, False, False]),
#  array([ True, False, False, False, False]),
#  array([ True,  True,  True,  True,  True]))

# %%
i = 1
plot_phased_LC(self, self.params_guess_priorto_confirm[i,0], self.params_guess_priorto_confirm[i,1])
