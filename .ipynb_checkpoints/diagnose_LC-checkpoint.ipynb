# %%
from diagnostics import *
# %matplotlib inline

# %%
# get data
planet, iteration = 37, 1
self = loadpickle('Results/TOIsensitivity27vettv3_mult2_planet%.5d_iteration%.3d/Sensitivity_class'%(planet,iteration))

# %%
#
plot_raw_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.934
# Ms       = 0.483
# Rs       = 0.455
# Teff     = 3627
# sig_phot = 496.8 ppm
#
# 2 injected planets:
# P  [days] = 0.816, 2.491
# rp        = 6.42, 5.80
# rp/Rs     = 0.12925, 0.11682
# (rp/Rs)^2 = 16706.310015, 13647.473381 ppm
# detected  = 1, 0
#
# 0 false positives:
# P [days] =

# %%
#
plot_corrected_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.934
# Ms       = 0.483
# Rs       = 0.455
# Teff     = 3627
# sig_phot = 496.8 ppm
#
# 2 injected planets:
# P  [days] = 0.816, 2.491
# rp        = 6.42, 5.80
# rp/Rs     = 0.12925, 0.11682
# (rp/Rs)^2 = 16706.310015, 13647.473381 ppm
# detected  = 1, 0
#
# 0 false positives:
# P [days] =

# %%
#
plot_transit_search(self, log=0)
# Out:
# Stellar parameters:
# Tmag     = 10.934
# Ms       = 0.483
# Rs       = 0.455
# Teff     = 3627
# sig_phot = 496.8 ppm
#
# 2 injected planets:
# P  [days] = 0.816, 2.491
# rp        = 6.42, 5.80
# rp/Rs     = 0.12925, 0.11682
# (rp/Rs)^2 = 16706.310015, 13647.473381 ppm
# detected  = 1, 0
#
# 0 false positives:
# P [days] =

# %%
#
check_confirm_transits(self, 1.6, 1., .42)
# Out:
# Confirming proposed transits...
# 0.0
# 0.25
# 0.5
# 0.75
# (array([[8.15506521e-01, 1.62580799e+03, 1.39612318e-02, 4.57302366e-02],
#         [3.53382483e+00, 1.63912784e+03, 7.36445860e-03, 5.27203759e-02],
#         [4.24107560e+00, 1.61846668e+03, 7.00313942e-03, 5.41898118e-02],
#         [5.98052207e+00, 1.63912807e+03, 9.43991922e-03, 5.93300841e-02]]),
#  array([[8.15506527e-01, 1.62580799e+03, 1.39612292e-02, 4.57302363e-02]]),
#  array([17256.99239171]),
#  array([ True,  True,  True,  True]),
#  array([ True,  True,  True,  True]),
#  array([ True, False, False, False]),
#  array([ True,  True,  True,  True]))

# %%
i = 1
plot_phased_LC(self, self.params_guess_priorto_confirm[i,0], self.params_guess_priorto_confirm[i,1])
