# %%
from diagnostics import *
# %matplotlib inline

# %%
# get data
self = loadpickle('Results/TOIsensitivity27vettv2_mult2_planet00026_iteration010/Sensitivity_class')

# %%
plot_raw_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.830
# Ms       = 0.608
# Rs       = 0.561
# Teff     = 3842
# sig_phot = 464.3 ppm
#
# 2 injected planets:
# P  [days] = 2.109, 4.184
# rp        = 1.28, 10.08
# rp/Rs     = 0.02083, 0.16461
# (rp/Rs)^2 = 433.900729, 27097.045317 ppm
# detected  = 0, 1
#
# 4 false positives:
# P [days] = 7.187, 9.549, 11.365, 13.739

# %%
plot_corrected_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.830
# Ms       = 0.608
# Rs       = 0.561
# Teff     = 3842
# sig_phot = 464.3 ppm
#
# 2 injected planets:
# P  [days] = 2.109, 4.184
# rp        = 1.28, 10.08
# rp/Rs     = 0.02083, 0.16461
# (rp/Rs)^2 = 433.900729, 27097.045317 ppm
# detected  = 0, 1
#
# 4 false positives:
# P [days] = 7.187, 9.549, 11.365, 13.739

# %%
plot_transit_search(self)
# Out:
# Stellar parameters:
# Tmag     = 10.830
# Ms       = 0.608
# Rs       = 0.561
# Teff     = 3842
# sig_phot = 464.3 ppm
#
# 2 injected planets:
# P  [days] = 2.109, 4.184
# rp        = 1.28, 10.08
# rp/Rs     = 0.02083, 0.16461
# (rp/Rs)^2 = 433.900729, 27097.045317 ppm
# detected  = 0, 1
#
# 4 false positives:
# P [days] = 7.187, 9.549, 11.365, 13.739

# %%
report_failed_planet_candidates(self)
# Out:
# Period = 4.184 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True
#
# Period = 7.188 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True
#
# Period = 9.548 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True
#
# Period = 11.365 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True
#
# Period = 13.761 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True

# %%
i = 0
plot_phased_LC(self, self.params_guess[i,0], self.params_guess[i,1])

# %%
# test FP identification technique
i=0
P,T0,_,dur = self.params_guess[i]
phase = foldAt(self.bjd, P, T0)
phase[phase>.5]-=1
intransit = (phase*P >= -dur/2) & (phase*P <= dur/2)

plt.plot(phase, self.fcorr,'.', phase[intransit], self.fcorr[intransit], '.')
plt.xlim((-.05,.05))

plt.figure()
y,x,p=plt.hist(self.fcorr[intransit], bins=30)
x = x[1:]-np.diff(x)[0]/2
plt.axvline(x.mean())

isFP = True if y[x>x.mean()].sum()/y.sum() >= .5 else False
print 'isFP?', isFP
# Out:
# isFP? False
