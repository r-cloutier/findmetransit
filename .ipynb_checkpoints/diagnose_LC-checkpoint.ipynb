# %%
from diagnostics import *
# %matplotlib inline

# %%
# get data
self = loadpickle('Results/TOIsensitivity27vettv2_mult2_planet00026_iteration018/Sensitivity_class')

# %%
#
plot_raw_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.430
# Ms       = 0.367
# Rs       = 0.360
# Teff     = 3448
# sig_phot = 358.3 ppm
#
# 2 injected planets:
# P  [days] = 1.783, 4.502
# rp        = 1.45, 4.29
# rp/Rs     = 0.03695, 0.10907
# (rp/Rs)^2 = 1365.648449, 11895.793100 ppm
# detected  = 0, 1
#
# 4 false positives:
# P [days] = 14.222, 15.158, 18.725, 20.510

# %%
#
plot_corrected_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.898
# Ms       = 0.655
# Rs       = 0.605
# Teff     = 3944
# sig_phot = 485.3 ppm
#
# 2 injected planets:
# P  [days] = 0.859, 2.089
# rp        = 3.41, 1.54
# rp/Rs     = 0.05164, 0.02336
# (rp/Rs)^2 = 2666.905733, 545.706084 ppm
# detected  = 1, 0
#
# 0 false positives:
# P [days] =

# %%
#
plot_transit_search(self)
# Out:
# Stellar parameters:
# Tmag     = 10.898
# Ms       = 0.655
# Rs       = 0.605
# Teff     = 3944
# sig_phot = 485.3 ppm
#
# 2 injected planets:
# P  [days] = 0.859, 2.089
# rp        = 3.41, 1.54
# rp/Rs     = 0.05164, 0.02336
# (rp/Rs)^2 = 2666.905733, 545.706084 ppm
# detected  = 1, 0
#
# 0 false positives:
# P [days] =

# %%
#
report_failed_planet_candidates(self)
# Out:
# Period = 0.859 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True

# %%
#
check_confirm_transits(self, 3, 3, .5)
# Out:
# Confirming proposed transits...
# 0.0
# (array([[8.59047642e-01, 1.63066670e+03, 1.76540838e-03, 4.64214180e-02]]),
#  array([[8.59047567e-01, 1.63066670e+03, 1.76702246e-03, 4.64442690e-02]]),
#  array([135813.62142876]),
#  array([ True]),
#  array([ True]),
#  array([ True]))

# %%
i = 1
plot_phased_LC(self, self.params_guess_priorto_confirm[i,0], self.params_guess_priorto_confirm[i,1])
