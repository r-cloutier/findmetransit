# %%
from diagnostics import *
# %matplotlib inline

# %%
# get data
self = loadpickle('Results/TOIsensitivity27vettv2_mult2_planet00026_iteration010/Sensitivity_class')

# %%
#
plot_raw_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.830
# Ms       = 0.608
# Rs       = 0.561
# Teff     = 3842
# sig_phot = 464.3 ppm
#
# 2 injected planets:
# P  [days] = 2.109, 4.184
# rp        = 1.28, 10.08
# rp/Rs     = 0.02083, 0.16461
# (rp/Rs)^2 = 433.900729, 27097.045317 ppm
# detected  = 0, 1
#
# 4 false positives:
# P [days] = 7.187, 9.549, 11.365, 13.739

# %%
#
plot_corrected_LC(self)
# Out:
# Stellar parameters:
# Tmag     = 10.830
# Ms       = 0.608
# Rs       = 0.561
# Teff     = 3842
# sig_phot = 464.3 ppm
#
# 2 injected planets:
# P  [days] = 2.109, 4.184
# rp        = 1.28, 10.08
# rp/Rs     = 0.02083, 0.16461
# (rp/Rs)^2 = 433.900729, 27097.045317 ppm
# detected  = 0, 1
#
# 4 false positives:
# P [days] = 7.187, 9.549, 11.365, 13.739

# %%
#
plot_transit_search(self)
# Out:
# Stellar parameters:
# Tmag     = 10.830
# Ms       = 0.608
# Rs       = 0.561
# Teff     = 3842
# sig_phot = 464.3 ppm
#
# 2 injected planets:
# P  [days] = 2.109, 4.184
# rp        = 1.28, 10.08
# rp/Rs     = 0.02083, 0.16461
# (rp/Rs)^2 = 433.900729, 27097.045317 ppm
# detected  = 0, 1
#
# 4 false positives:
# P [days] = 7.187, 9.549, 11.365, 13.739

# %%
#
report_failed_planet_candidates(self)
# Out:
# Period = 4.184 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True
#
# Period = 7.188 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True
#
# Period = 9.548 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True
#
# Period = 11.365 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True
#
# Period = 13.761 days
# is median flux in-transit significantly deeper than out of transit?
# True
# is transit depth S/N greater than the required threshold?
# True

# %%
#
check_confirm_transits(self, 3, 3, .5)
# Out:
# Confirming proposed transits...
# 0.0
# 0.2
# 0.4
# 0.6
# 0.8
# (array([[4.18375520e+00, 1.62558314e+03, 2.47785360e-02, 9.61550950e-02],
#         [7.18780056e+00, 1.63395066e+03, 1.26355680e-02, 9.43618913e-02],
#         [9.54816804e+00, 1.62676374e+03, 1.30462076e-02, 9.80167954e-02],
#         [1.13654446e+01, 1.63813442e+03, 1.32253377e-02, 1.00262877e-01],
#         [1.37608522e+01, 1.62679281e+03, 2.67056730e-02, 1.10077805e-01]]),
#  array([[4.18375520e+00, 1.62558314e+03, 2.47785364e-02, 9.61550914e-02],
#         [1.37391844e+01, 1.62677113e+03, 2.67921489e-02, 1.10393968e-01]]),
#  array([ 139176.03670906, -431392.50905153]),
#  array([ True,  True,  True,  True,  True]),
#  array([ True,  True,  True,  True,  True]),
#  array([ True, False, False, False,  True]))

# %%
i = 4
plot_phased_LC(self, self.params_guess_priorto_confirm[i,0], self.params_guess_priorto_confirm[i,1])

# %%
P1, P2 = self.params_guess_priorto_confirm[np.array([0,4]),0]
#P1 = self.params_true[0,0]
P1, P2
# Out:
# (4.183755198828197, 13.76085219349915)

# %%
P1*3, P2*.99
# Out:
# (12.55126559648459, 13.62324367156416)

# %%
np.isclose(P1*9, P2, atol=.2), np.isclose(P1*3, P2, rtol=.02)
# Out:
# (False, False)

# %%
bjd=self.bjd
Ntransits = int((bjd.max()-bjd.min()) / P1)
lim = Ntransits+1 if Ntransits+1 > 2 else 3
lim
# Out:
# 7
